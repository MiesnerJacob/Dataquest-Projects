# %% [markdown]
# # Guided Project: Winning Jeopardy (Hypothesis Testing)
#
# Jeopardy is a popular TV show in the US where participants answer questions to win money. It's been running for a few decades, and is a major force in popular culture. If you need help at any point, you can consult our solution notebook here.
#
# Let's say you want to compete on Jeopardy, and you're looking for any edge you can get to win. In this project, I will work with a dataset of Jeopardy questions to figure out some patterns in the questions that could help you win.

# %%
import pandas as pd
import numpy as np
import re
from scipy.stats import chisquare

# %%
jeopardy = pd.read_json('/Users/miesner.jacob/Desktop/DataQuest/JEOPARDY_QUESTIONS.json')

# %% [markdown]
# ## Data Exploration

# %%
jeopardy.head(5)
# Out:
#      air_date       answer                         category  \
# 0  2004-12-31   Copernicus                          HISTORY
# 1  2004-12-31   Jim Thorpe  ESPN's TOP 10 ALL-TIME ATHLETES
# 2  2004-12-31      Arizona      EVERYBODY TALKS ABOUT IT...
# 3  2004-12-31  McDonald\'s                 THE COMPANY LINE
# 4  2004-12-31   John Adams              EPITAPHS & TRIBUTES
#
#                                             question      round  show_number  \
# 0  'For the last 8 years of his life, Galileo was...  Jeopardy!         4680
# 1  'No. 2: 1912 Olympian; football star at Carlis...  Jeopardy!         4680
# 2  'The city of Yuma in this state has a record a...  Jeopardy!         4680
# 3  'In 1963, live on "The Art Linkletter Show", t...  Jeopardy!         4680
# 4  'Signer of the Dec. of Indep., framer of the C...  Jeopardy!         4680
#
#   value
# 0  $200
# 1  $200
# 2  $200
# 3  $200
# 4  $200

# %%
jeopardy.shape
# Out:
# (216930, 7)

# %%
jeopardy.columns
# Out:
# Index(['air_date', 'answer', 'category', 'question', 'round', 'show_number',
#        'value'],
#       dtype='object')

# %%
jeopardy.columns = jeopardy.columns.str.strip()

# %%
jeopardy
# Out:
#           air_date                                             answer  \
# 0       2004-12-31                                         Copernicus
# 1       2004-12-31                                         Jim Thorpe
# 2       2004-12-31                                            Arizona
# 3       2004-12-31                                        McDonald\'s
# 4       2004-12-31                                         John Adams
# 5       2004-12-31                                            the ant
# 6       2004-12-31                                     the Appian Way
# 7       2004-12-31                                     Michael Jordan
# 8       2004-12-31                                         Washington
# 9       2004-12-31                                     Crate & Barrel
# 10      2004-12-31                                     Jackie Gleason
# 11      2004-12-31                                            the cud
# 12      2004-12-31                              Ceylon (or Sri Lanka)
# 13      2004-12-31                                          Jim Brown
# 14      2004-12-31                                       the UV index
# 15      2004-12-31                                             Bulova
# 16      2004-12-31                                        Jesse James
# 17      2004-12-31                                                imp
# 18      2004-12-31                                  the International
# 19      2004-12-31                                       (Lou) Gehrig
# 20      2004-12-31                                            Morocco
# 21      2004-12-31                                      (Paul) Bonwit
# 22      2004-12-31  Hattie McDaniel (for her role in Gone with the...
# 23      2004-12-31                                                era
# 24      2004-12-31                                 the Congress Party
# 25      2004-12-31                                 (Wilt) Chamberlain
# 26      2004-12-31                                                 K2
# 27      2004-12-31                                        Ethan Allen
# 28      2004-12-31                                                ply
# 29      2004-12-31                                             Horton
# ...            ...                                                ...
# 216900  2006-05-11                                       Alec Baldwin
# 216901  2006-05-11                                             Samson
# 216902  2006-05-11                                           the teal
# 216903  2006-05-11                                             Africa
# 216904  2006-05-11                                      Ronald Reagan
# 216905  2006-05-11                                           Budapest
# 216906  2006-05-11                                          Amsterdam
# 216907  2006-05-11                                                man
# 216908  2006-05-11                                           a toucan
# 216909  2006-05-11                                     Allen Ginsberg
# 216910  2006-05-11                                       Muhammad Ali
# 216911  2006-05-11                                               Oslo
# 216912  2006-05-11                                         Siddhartha
# 216913  2006-05-11                                     (Edward) Elgar
# 216914  2006-05-11                                             a tern
# 216915  2006-05-11                             (Erle Stanley) Gardner
# 216916  2006-05-11                                               work
# 216917  2006-05-11                                         Georgetown
# 216918  2006-05-11                                         Fanny Hill
# 216919  2006-05-11                                           Magritte
# 216920  2006-05-11                                           thrushes
# 216921  2006-05-11                                          Anaïs Nin
# 216922  2006-05-11                                (Margaret) Thatcher
# 216923  2006-05-11                                         Paramaribo
# 216924  2006-05-11                                              Stomp
# 216925  2006-05-11                                           Turandot
# 216926  2006-05-11                                         a titmouse
# 216927  2006-05-11                                       Clive Barker
# 216928  2006-05-11                                           Geronimo
# 216929  2006-05-11                     Grigori Alexandrovich Potemkin
#
#                                category  \
# 0                               HISTORY
# 1       ESPN's TOP 10 ALL-TIME ATHLETES
# 2           EVERYBODY TALKS ABOUT IT...
# 3                      THE COMPANY LINE
# 4                   EPITAPHS & TRIBUTES
# 5                        3-LETTER WORDS
# 6                               HISTORY
# 7       ESPN's TOP 10 ALL-TIME ATHLETES
# 8           EVERYBODY TALKS ABOUT IT...
# 9                      THE COMPANY LINE
# 10                  EPITAPHS & TRIBUTES
# 11                       3-LETTER WORDS
# 12                              HISTORY
# 13      ESPN's TOP 10 ALL-TIME ATHLETES
# 14          EVERYBODY TALKS ABOUT IT...
# 15                     THE COMPANY LINE
# 16                  EPITAPHS & TRIBUTES
# 17                       3-LETTER WORDS
# 18                              HISTORY
# 19      ESPN's TOP 10 ALL-TIME ATHLETES
# 20          EVERYBODY TALKS ABOUT IT...
# 21                     THE COMPANY LINE
# 22                  EPITAPHS & TRIBUTES
# 23                       3-LETTER WORDS
# 24                              HISTORY
# 25      ESPN's TOP 10 ALL-TIME ATHLETES
# 26                     THE COMPANY LINE
# 27                  EPITAPHS & TRIBUTES
# 28                       3-LETTER WORDS
# 29           DR. SEUSS AT THE MULTIPLEX
# ...                                 ...
# 216900                     OFF-BROADWAY
# 216901                   RIDDLE ME THIS
# 216902                        "T" BIRDS
# 216903           AUTHORS IN THEIR YOUTH
# 216904                       QUOTATIONS
# 216905                   WORLD CAPITALS
# 216906                     OFF-BROADWAY
# 216907                   RIDDLE ME THIS
# 216908                        "T" BIRDS
# 216909           AUTHORS IN THEIR YOUTH
# 216910                       QUOTATIONS
# 216911                   WORLD CAPITALS
# 216912                     OFF-BROADWAY
# 216913                   RIDDLE ME THIS
# 216914                        "T" BIRDS
# 216915           AUTHORS IN THEIR YOUTH
# 216916                       QUOTATIONS
# 216917                   WORLD CAPITALS
# 216918                     OFF-BROADWAY
# 216919                   RIDDLE ME THIS
# 216920                        "T" BIRDS
# 216921           AUTHORS IN THEIR YOUTH
# 216922                       QUOTATIONS
# 216923                   WORLD CAPITALS
# 216924                     OFF-BROADWAY
# 216925                   RIDDLE ME THIS
# 216926                        "T" BIRDS
# 216927           AUTHORS IN THEIR YOUTH
# 216928                       QUOTATIONS
# 216929                   HISTORIC NAMES
#
#                                                  question             round  \
# 0       'For the last 8 years of his life, Galileo was...         Jeopardy!
# 1       'No. 2: 1912 Olympian; football star at Carlis...         Jeopardy!
# 2       'The city of Yuma in this state has a record a...         Jeopardy!
# 3       'In 1963, live on "The Art Linkletter Show", t...         Jeopardy!
# 4       'Signer of the Dec. of Indep., framer of the C...         Jeopardy!
# 5       'In the title of an Aesop fable, this insect s...         Jeopardy!
# 6       'Built in 312 B.C. to link Rome & the South of...         Jeopardy!
# 7       'No. 8: 30 steals for the Birmingham Barons; 2...         Jeopardy!
# 8       'In the winter of 1971-72, a record 1,122 inch...         Jeopardy!
# 9       'This housewares store was named for the packa...         Jeopardy!
# 10                                     '"And away we go"'         Jeopardy!
# 11      'Cows regurgitate this from the first stomach ...         Jeopardy!
# 12      'In 1000 Rajaraja I of the Cholas battled to t...         Jeopardy!
# 13      'No. 1: Lettered in hoops, football & lacrosse...         Jeopardy!
# 14      'On June 28, 1994 the nat'l weather service be...         Jeopardy!
# 15      'This company's Accutron watch, introduced in ...         Jeopardy!
# 16      'Outlaw: "Murdered by a traitor and a coward w...         Jeopardy!
# 17      'A small demon, or a mischievous child (who mi...         Jeopardy!
# 18      'Karl led the first of these Marxist organizat...         Jeopardy!
# 19      'No. 10: FB/LB for Columbia U. in the 1920s; M...         Jeopardy!
# 20      'Africa's lowest temperature was 11 degrees be...         Jeopardy!
# 21      'Edward Teller & this man partnered in 1898 to...         Jeopardy!
# 22      '1939 Oscar winner: "...you are a credit to yo...         Jeopardy!
# 23      'In geologic time one of these, shorter than a...         Jeopardy!
# 24      'This Asian political party was founded in 188...         Jeopardy!
# 25      'No. 5: Only center to lead the NBA in assists...         Jeopardy!
# 26      'The Kirschner brothers, Don & Bill, named thi...         Jeopardy!
# 27      'Revolutionary War hero: "His spirit is in Ver...         Jeopardy!
# 28      'A single layer of paper, or to perform one's ...         Jeopardy!
# 29      '<a href="http://www.j-archive.com/media/2004-...  Double Jeopardy!
# ...                                                   ...               ...
# 216900  'This Baldwin brother was extremely entertaini...  Double Jeopardy!
# 216901  'He used the strength of his mind when he prop...  Double Jeopardy!
# 216902  'Common species of this duck include blue-wing...  Double Jeopardy!
# 216903  'As a child, Joseph Conrad pointed to the cent...  Double Jeopardy!
# 216904  'In 1981 he quipped, "You can tell a lot about...  Double Jeopardy!
# 216905  'It has a museum devoted to composer Zoltan Ko...  Double Jeopardy!
# 216906  '"Red Light Winter" centers on a love triangle...  Double Jeopardy!
# 216907  'Sphinx: What animal walks on 4 legs in the mo...  Double Jeopardy!
# 216908  'Toco, the largest species of this colorful bi...  Double Jeopardy!
# 216909  'Poet Gregory Corso went on the beat path afte...  Double Jeopardy!
# 216910  'In his prime this athlete said, It's hard to ...  Double Jeopardy!
# 216911           'It's home to the Holmenkollen ski jump'  Double Jeopardy!
# 216912  'We'd like to "enlighten" you about the musica...  Double Jeopardy!
# 216913  'He created the musical riddles called the "En...  Double Jeopardy!
# 216914  'One species of this bird breeds in the Arctic...  Double Jeopardy!
# 216915  'In his teens he worked in an assistant D.A.'s...  Double Jeopardy!
# 216916  'Oscar Wilde called this 4-letter word "the cu...  Double Jeopardy!
# 216917  'Guyanese capital named for a Hanoverian monarch'  Double Jeopardy!
# 216918  'A naughty 18th c. novel originally titled "Me...  Double Jeopardy!
# 216919  'If this riddling Belgian surrealist painter, ...  Double Jeopardy!
# 216920  'Nightingales & robins belong to this family o...  Double Jeopardy!
# 216921  'Her hotsy-totsy diaries trace back to one she...  Double Jeopardy!
# 216922  'A motto of hers was "in politics, if you want...  Double Jeopardy!
# 216923                       'It's on the Suriname River'  Double Jeopardy!
# 216924  'In 2006 the cast of this long-running hit emb...  Double Jeopardy!
# 216925  'This Puccini opera turns on the solution to 3...  Double Jeopardy!
# 216926  'In North America this term is properly applie...  Double Jeopardy!
# 216927  'In Penny Lane, where this "Hellraiser" grew u...  Double Jeopardy!
# 216928  'From Ft. Sill, Okla. he made the plea, Arizon...  Double Jeopardy!
# 216929  'A silent movie title includes the last name o...   Final Jeopardy!
#
#         show_number   value
# 0              4680    $200
# 1              4680    $200
# 2              4680    $200
# 3              4680    $200
# 4              4680    $200
# 5              4680    $200
# 6              4680    $400
# 7              4680    $400
# 8              4680    $400
# 9              4680    $400
# 10             4680    $400
# 11             4680    $400
# 12             4680    $600
# 13             4680    $600
# 14             4680    $600
# 15             4680    $600
# 16             4680    $600
# 17             4680    $600
# 18             4680    $800
# 19             4680    $800
# 20             4680    $800
# 21             4680    $800
# 22             4680  $2,000
# 23             4680    $800
# 24             4680   $1000
# 25             4680   $1000
# 26             4680   $1000
# 27             4680   $1000
# 28             4680   $1000
# 29             4680    $400
# ...             ...     ...
# 216900         4999    $400
# 216901         4999    $400
# 216902         4999    $400
# 216903         4999    $400
# 216904         4999    $400
# 216905         4999    $800
# 216906         4999    $800
# 216907         4999    $800
# 216908         4999    $800
# 216909         4999    $800
# 216910         4999    $800
# 216911         4999   $1200
# 216912         4999   $1200
# 216913         4999   $1200
# 216914         4999   $1200
# 216915         4999   $1200
# 216916         4999  $2,200
# 216917         4999  $3,400
# 216918         4999   $1600
# 216919         4999   $1600
# 216920         4999   $1600
# 216921         4999   $1600
# 216922         4999   $1600
# 216923         4999   $2000
# 216924         4999   $2000
# 216925         4999   $2000
# 216926         4999   $2000
# 216927         4999   $2000
# 216928         4999   $2000
# 216929         4999    None
#
# [216930 rows x 7 columns]

# %% [markdown]
# ## Data Cleaning

# %%
def normalize_string(string):
    string = string.lower()
    string = re.sub("[^A-Za-z0-9\s]","",string)
    return string

# %%
jeopardy['clean_question'] = jeopardy['question'].apply(normalize_string)
jeopardy['clean_answer'] = jeopardy['answer'].apply(normalize_string)

# %%
def normalize_dollars(string):
    string = re.sub("[^A-Za-z0-9\s]","",str(string))
    try:
        string = int(string)
    except:
        string = 0
    return string

# %%
jeopardy['clean_value'] = jeopardy['value'].apply(normalize_dollars)

# %%
jeopardy['air_date'] = pd.to_datetime(jeopardy['air_date'])

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# In order to figure out whether to study past questions, study general knowledge, or not study it all, it would be helpful to figure out two things:
#
# * How often the answer is deducible from the question.
# * How often new questions are repeats of older questions.
#
# You can answer the second question by seeing how often complex words (> 6 characters) reoccur. You can answer the first question by seeing how many times words in the answer also occur in the question. We'll work on the first question now, and come back to the second.

# %%
def answer_question(row):
    split_answer = row['clean_answer'].split(" ")
    split_question = row['clean_question'].split(" ")
    if "the" in split_answer:
        split_answer.remove("the")
    if len(split_answer) == 0:
        return 0
    match_count = 0
    for item in split_answer:
        if item in split_question:
            match_count += 1
    return match_count / len(split_answer)

# %%
jeopardy["answer_in_question"] = jeopardy.apply(answer_question, axis=1)

# %%
jeopardy['answer_in_question'].mean()
# Out:
# 0.05776013093881471

# %% [markdown]
# Answer terms in the question
#
# The answer only appears in the question 5.7% of the time. This means that you should probably study and not rely only on deducing the answer from the question.

# %%
question_overlap = []
terms_used = set()

jeopardy = jeopardy.sort_values('air_date').reset_index(drop=True)

for i, row in jeopardy.iterrows():
        split_question = row["clean_question"].split(" ")
        split_question = [q for q in split_question if len(q) > 5]
        match_count = 0
        for word in split_question:
            if word in terms_used:
                match_count += 1
        for word in split_question:
            terms_used.add(word)
        if len(split_question) > 0:
            match_count /= len(split_question)
        question_overlap.append(match_count)
jeopardy["question_overlap"] = question_overlap

jeopardy["question_overlap"].mean()
# Out:
# 0.8654721654522508

# %% [markdown]
# Question overlap
#
# There is about 87% overlap between terms in new questions and terms in old questions. This only looks at a small set of questions and it only looks at single terms longer than five characters long. This means that it is not as significantly as the percentage would seem, but it is worth studying old questions.

# %% [markdown]
# Let's say you only want to study questions that pertain to high value questions instead of low value questions. This will help you earn more money when you're on Jeopardy.
#
# You can actually figure out which terms correspond to high-value questions using a chi-squared test. First I will need to narrow down the questions into two categories:
#
# * Low value -- Any row where Value is less than 800.
# * High value -- Any row where Value is greater than 800.

# %%
def valuefier(row):
    if row['clean_value'] > 800:
        value = 1
    else:
        value = 0
    return value

# %%
jeopardy['high_value'] = jeopardy.apply(valuefier, axis = 1)

# %%
jeopardy
# Out:
#          air_date                                answer  \
# 0      1984-09-10                            the Jordan
# 1      1984-09-10                     Independence Hall
# 2      1984-09-10                     the love of money
# 3      1984-09-10                            Mr. Wizard
# 4      1984-09-10                           the Capitol
# 5      1984-09-10                     John Wilkes Booth
# 6      1984-09-10                                  oath
# 7      1984-09-10                Martin Luther King Day
# 8      1984-09-10                          Sean Connery
# 9      1984-09-10                              a blintz
# 10     1984-09-10                                  what
# 11     1984-09-10                          the Missouri
# 12     1984-09-10                       the Volga River
# 13     1984-09-10                                  rats
# 14     1984-09-10                               chicken
# 15     1984-09-10                            "Thriller"
# 16     1984-09-10                                  loch
# 17     1984-09-10                              freezing
# 18     1984-09-10                             the trunk
# 19     1984-09-10                               sausage
# 20     1984-09-10            Dan Aykroyd & Eddie Murphy
# 21     1984-09-10                          the rickshaw
# 22     1984-09-10                             the radio
# 23     1984-09-10                             Eve Arden
# 24     1984-09-10                                weasel
# 25     1984-09-10                                  Nero
# 26     1984-09-10                             Jerusalem
# 27     1984-09-10                 the Statue of Liberty
# 28     1984-09-10  private eyes (or private detectives)
# 29     1984-09-10                             the walls
# ...           ...                                   ...
# 216900 2012-01-27                       Kristen Stewart
# 216901 2012-01-27               "America the Beautiful"
# 216902 2012-01-27                           the Capitol
# 216903 2012-01-27                                  rein
# 216904 2012-01-27                              Pakistan
# 216905 2012-01-27                          W. C. Fields
# 216906 2012-01-27                                   ere
# 216907 2012-01-27                digitalis (or digoxin)
# 216908 2012-01-27                               Seville
# 216909 2012-01-27                               Elliott
# 216910 2012-01-27                     Central Park West
# 216911 2012-01-27                                 Miami
# 216912 2012-01-27                    the Mosquito Coast
# 216913 2012-01-27                     the metric system
# 216914 2012-01-27                            plus fours
# 216915 2012-01-27                                     M
# 216916 2012-01-27                                  here
# 216917 2012-01-27                           Jaden Smith
# 216918 2012-01-27                        toreador pants
# 216919 2012-01-27                                Sydney
# 216920 2012-01-27                             a compass
# 216921 2012-01-27                                 There
# 216922 2012-01-27                        photosynthesis
# 216923 2012-01-27                                    He
# 216924 2012-01-27                               Toronto
# 216925 2012-01-27                            luau pants
# 216926 2012-01-27                       The Brady Bunch
# 216927 2012-01-27                              aluminum
# 216928 2012-01-27                              Salzburg
# 216929 2012-01-27                           cargo pants
#
#                        category  \
# 0                LAKES & RIVERS
# 1            NATIONAL LANDMARKS
# 2                     THE BIBLE
# 3                      '50'S TV
# 4            NATIONAL LANDMARKS
# 5                     NOTORIOUS
# 6                4-LETTER WORDS
# 7                      HOLIDAYS
# 8                ACTORS & ROLES
# 9               FOREIGN CUISINE
# 10               4-LETTER WORDS
# 11               LAKES & RIVERS
# 12               LAKES & RIVERS
# 13                      ANIMALS
# 14              FOREIGN CUISINE
# 15               ACTORS & ROLES
# 16               LAKES & RIVERS
# 17                   INVENTIONS
# 18                      ANIMALS
# 19              FOREIGN CUISINE
# 20               ACTORS & ROLES
# 21                   INVENTIONS
# 22                   INVENTIONS
# 23                     '50'S TV
# 24                      ANIMALS
# 25                    NOTORIOUS
# 26                    THE BIBLE
# 27           NATIONAL LANDMARKS
# 28                     '50'S TV
# 29                    THE BIBLE
# ...                         ...
# 216900             CHILD ACTORS
# 216901           STUPID ANSWERS
# 216902           STUPID ANSWERS
# 216903   THE TRUTH LIES THEREIN
# 216904                    PANTS
# 216905             CHILD ACTORS
# 216906   THE TRUTH LIES THEREIN
# 216907  LESSER-KNOWN SCIENTISTS
# 216908        VISITING THE CITY
# 216909             CHILD ACTORS
# 216910           STUPID ANSWERS
# 216911        VISITING THE CITY
# 216912           STUPID ANSWERS
# 216913  LESSER-KNOWN SCIENTISTS
# 216914                    PANTS
# 216915           STUPID ANSWERS
# 216916   THE TRUTH LIES THEREIN
# 216917             CHILD ACTORS
# 216918                    PANTS
# 216919        VISITING THE CITY
# 216920  LESSER-KNOWN SCIENTISTS
# 216921   THE TRUTH LIES THEREIN
# 216922  LESSER-KNOWN SCIENTISTS
# 216923   THE TRUTH LIES THEREIN
# 216924        VISITING THE CITY
# 216925                    PANTS
# 216926             CHILD ACTORS
# 216927  LESSER-KNOWN SCIENTISTS
# 216928        VISITING THE CITY
# 216929                    PANTS
#
#                                                  question             round  \
# 0               'River mentioned most often in the Bible'         Jeopardy!
# 1       'Site where John Hancock signed his "John Hanc...  Double Jeopardy!
# 2       'According to 1st Timothy, it is the "root of ...  Double Jeopardy!
# 3       'Name under which experimenter Don Herbert tau...  Double Jeopardy!
# 4       'D.C. building shaken by November '83 bomb blast'  Double Jeopardy!
# 5       'After the deed, he leaped to the stage shouti...  Double Jeopardy!
# 6       'The president takes one before stepping into ...  Double Jeopardy!
# 7          'The third Monday of January starting in 1986'   Final Jeopardy!
# 8       'He may "Never Say Never Again" when asked to ...         Jeopardy!
# 9                       'Jewish crepe filled with cheese'         Jeopardy!
# 10      'It's the first 4-letter word in "The Star Spa...  Double Jeopardy!
# 11      'American river only 33 miles shorter than the...         Jeopardy!
# 12      'River in <a href="http://www.j-archive.com/me...         Jeopardy!
# 13      'These rodents first got to America by stowing...         Jeopardy!
# 14                              'The "coq" in coq au vin'         Jeopardy!
# 15      'Video in which Michael Jackson plays a werewo...         Jeopardy!
# 16                               'Scottish word for lake'         Jeopardy!
# 17      'A 1920's hunting trip to Canada inspired Bird...         Jeopardy!
# 18      'There are about 40,000 muscles & tendons in t...         Jeopardy!
# 19      'A British variety is called "bangers", a Mexi...         Jeopardy!
# 20      '2 "Saturday Night" alumni who tried "Trading ...         Jeopardy!
# 21      'In 1869 an American minister created this "or...         Jeopardy!
# 22                         'Marconi's wonderful wireless'         Jeopardy!
# 23                            'She was "Our Miss Brooks"'  Double Jeopardy!
# 24      'When husbands "pop" for an ermine coat, they'...         Jeopardy!
# 25      'It was probably a lyre, not a fiddle, if he p...  Double Jeopardy!
# 26      'Though its name means "city of peace", it's s...  Double Jeopardy!
# 27      'She came from France to harbor America's free...  Double Jeopardy!
# 28      'Occupation of Richard Diamond, Peter Gunn & M...  Double Jeopardy!
# 29      'When "Joshua Fit The Battle Of Jericho", thes...  Double Jeopardy!
# ...                                                   ...               ...
# 216900  'At age 11, this future portrayer of Bella Swa...         Jeopardy!
# 216901  'The second verse of this classic American son...         Jeopardy!
# 216902  'This building in our national capital was ori...         Jeopardy!
# 216903                                  'Colt controller'         Jeopardy!
# 216904  'The baggy shalwar is always in fashion in thi...         Jeopardy!
# 216905  'In the 1930s Baby LeRoy played opposite this ...         Jeopardy!
# 216906            'A palindromic preposition of the past'         Jeopardy!
# 216907  'In 1785 William Withering suggested using thi...         Jeopardy!
# 216908  'Arriving at the train station built for the 1...         Jeopardy!
# 216909  'Henry Thomas, who played this role in "E.T.",...         Jeopardy!
# 216910  'On the west, Central Park is bounded by this ...         Jeopardy!
# 216911  'Experience Little Havana along Calle Ocho, th...         Jeopardy!
# 216912  'The Mosquito Indians are a majority populatio...         Jeopardy!
# 216913  'Joseph Lagrange insisted on 10 as the basic u...         Jeopardy!
# 216914  'When introduced, these wide, baggy pants were...         Jeopardy!
# 216915  'This was first imprinted in black on individu...         Jeopardy!
# 216916  'Old school GPS on a shopping mall map:  "You ...         Jeopardy!
# 216917  'This kid, with a familiar last name, is seen ...         Jeopardy!
# 216918  'Tight-fitting pants patterned after those wor...         Jeopardy!
# 216919  'There's a great opera house on Bennelong Poin...         Jeopardy!
# 216920  'Gowin Knight's 1745 development of a better w...         Jeopardy!
# 216921     'Old school CBS history show:  "You Are" this'         Jeopardy!
# 216922  'In 1779 Dutch scientist Jan Ingenhousz publis...         Jeopardy!
# 216923           'Symbol for the second-lightest element'         Jeopardy!
# 216924  'First the Royal Ontario Museum, then for lunc...         Jeopardy!
# 216925  'Calf-length pants styled in colorful island p...         Jeopardy!
# 216926  'Scott Lookinland played his father, Mike, in ...         Jeopardy!
# 216927  'The "crown jewels" of Alcoa are the bits of t...         Jeopardy!
# 216928  'Take the "Sound of Music" tour or visit the H...         Jeopardy!
# 216929  'A synonym for freight, or pants with large be...         Jeopardy!
#
#         show_number   value  \
# 0                 1    $100
# 1                 1    $800
# 2                 1   $1000
# 3                 1   $1000
# 4                 1   $1000
# 5                 1   $1000
# 6                 1   $1000
# 7                 1    None
# 8                 1    $300
# 9                 1    $300
# 10                1  $1,000
# 11                1    $400
# 12                1    $800
# 13                1    $100
# 14                1    $100
# 15                1    $100
# 16                1    $200
# 17                1    $300
# 18                1    $200
# 19                1    $200
# 20                1    $200
# 21                1    $200
# 22                1    $100
# 23                1    $400
# 24                1    $300
# 25                1    $200
# 26                1    $800
# 27                1    $200
# 28                1    $200
# 29                1    $200
# ...             ...     ...
# 216900         6300    $600
# 216901         6300    $800
# 216902         6300    $400
# 216903         6300    $800
# 216904         6300   $1000
# 216905         6300   $1000
# 216906         6300   $1000
# 216907         6300   $1000
# 216908         6300   $1000
# 216909         6300    $200
# 216910         6300    $200
# 216911         6300    $200
# 216912         6300   $1000
# 216913         6300    $800
# 216914         6300    $600
# 216915         6300    $600
# 216916         6300    $400
# 216917         6300    $800
# 216918         6300  $1,400
# 216919         6300    $800
# 216920         6300    $600
# 216921         6300    $600
# 216922         6300    $200
# 216923         6300    $200
# 216924         6300    $400
# 216925         6300    $400
# 216926         6300    $400
# 216927         6300    $400
# 216928         6300    $600
# 216929         6300    $200
#
#                                            clean_question  \
# 0                 river mentioned most often in the bible
# 1         site where john hancock signed his john hancock
# 2       according to 1st timothy it is the root of all...
# 3       name under which experimenter don herbert taug...
# 4            dc building shaken by november 83 bomb blast
# 5       after the deed he leaped to the stage shouting...
# 6       the president takes one before stepping into o...
# 7            the third monday of january starting in 1986
# 8       he may never say never again when asked to be ...
# 9                         jewish crepe filled with cheese
# 10      its the first 4letter word in the star spangle...
# 11      american river only 33 miles shorter than the ...
# 12      river in a hrefhttpwwwjarchivecommedia19840910...
# 13      these rodents first got to america by stowing ...
# 14                                  the coq in coq au vin
# 15      video in which michael jackson plays a werewol...
# 16                                 scottish word for lake
# 17      a 1920s hunting trip to canada inspired birdse...
# 18      there are about 40000 muscles  tendons in this...
# 19      a british variety is called bangers a mexican ...
# 20       2 saturday night alumni who tried trading places
# 21      in 1869 an american minister created this orie...
# 22                            marconis wonderful wireless
# 23                                she was our miss brooks
# 24      when husbands pop for an ermine coat theyre ac...
# 25      it was probably a lyre not a fiddle if he play...
# 26      though its name means city of peace its seen o...
# 27        she came from france to harbor americas freedom
# 28      occupation of richard diamond peter gunn  mike...
# 29      when joshua fit the battle of jericho these to...
# ...                                                   ...
# 216900  at age 11 this future portrayer of bella swan ...
# 216901  the second verse of this classic american song...
# 216902  this building in our national capital was orig...
# 216903                                    colt controller
# 216904  the baggy shalwar is always in fashion in this...
# 216905  in the 1930s baby leroy played opposite this c...
# 216906              a palindromic preposition of the past
# 216907  in 1785 william withering suggested using this...
# 216908  arriving at the train station built for the 19...
# 216909  henry thomas who played this role in et turned...
# 216910  on the west central park is bounded by this st...
# 216911  experience little havana along calle ocho then...
# 216912  the mosquito indians are a majority population...
# 216913  joseph lagrange insisted on 10 as the basic un...
# 216914  when introduced these wide baggy pants were 4 ...
# 216915  this was first imprinted in black on individua...
# 216916  old school gps on a shopping mall map  you are...
# 216917  this kid with a familiar last name is seen a h...
# 216918  tightfitting pants patterned after those worn ...
# 216919  theres a great opera house on bennelong point ...
# 216920  gowin knights 1745 development of a better way...
# 216921          old school cbs history show  you are this
# 216922  in 1779 dutch scientist jan ingenhousz publish...
# 216923              symbol for the secondlightest element
# 216924  first the royal ontario museum then for lunch ...
# 216925  calflength pants styled in colorful island pri...
# 216926  scott lookinland played his father mike in the...
# 216927  the crown jewels of alcoa are the bits of this...
# 216928  take the sound of music tour or visit the hage...
# 216929  a synonym for freight or pants with large bell...
#
#                               clean_answer  clean_value  answer_in_question  \
# 0                               the jordan          100            0.000000
# 1                        independence hall          800            0.000000
# 2                        the love of money         1000            0.333333
# 3                                mr wizard         1000            0.000000
# 4                              the capitol         1000            0.000000
# 5                        john wilkes booth         1000            0.000000
# 6                                     oath         1000            0.000000
# 7                   martin luther king day            0            0.000000
# 8                             sean connery          300            0.000000
# 9                                 a blintz          300            0.000000
# 10                                    what         1000            0.000000
# 11                            the missouri          400            0.000000
# 12                         the volga river          800            0.500000
# 13                                    rats          100            0.000000
# 14                                 chicken          100            0.000000
# 15                                thriller          100            0.000000
# 16                                    loch          200            0.000000
# 17                                freezing          300            0.000000
# 18                               the trunk          200            0.000000
# 19                                 sausage          200            0.000000
# 20               dan aykroyd  eddie murphy          200            0.000000
# 21                            the rickshaw          200            0.000000
# 22                               the radio          100            0.000000
# 23                               eve arden          400            0.000000
# 24                                  weasel          300            0.000000
# 25                                    nero          200            0.000000
# 26                               jerusalem          800            0.000000
# 27                   the statue of liberty          200            0.000000
# 28      private eyes or private detectives          200            0.000000
# 29                               the walls          200            0.000000
# ...                                    ...          ...                 ...
# 216900                     kristen stewart          600            0.000000
# 216901               america the beautiful          800            0.500000
# 216902                         the capitol          400            0.000000
# 216903                                rein          800            0.000000
# 216904                            pakistan         1000            0.000000
# 216905                          w c fields         1000            0.000000
# 216906                                 ere         1000            0.000000
# 216907                digitalis or digoxin         1000            0.000000
# 216908                             seville         1000            0.000000
# 216909                             elliott          200            0.000000
# 216910                   central park west          200            1.000000
# 216911                               miami          200            0.000000
# 216912                  the mosquito coast         1000            0.500000
# 216913                   the metric system          800            0.500000
# 216914                          plus fours          600            0.000000
# 216915                                   m          600            0.000000
# 216916                                here          400            0.000000
# 216917                         jaden smith          800            0.000000
# 216918                      toreador pants         1400            0.500000
# 216919                              sydney          800            0.000000
# 216920                           a compass          600            0.500000
# 216921                               there          600            0.000000
# 216922                      photosynthesis          200            0.000000
# 216923                                  he          200            0.000000
# 216924                             toronto          400            0.000000
# 216925                          luau pants          400            0.500000
# 216926                     the brady bunch          400            0.000000
# 216927                            aluminum          400            0.000000
# 216928                            salzburg          600            0.000000
# 216929                         cargo pants          200            0.500000
#
#         question_overlap  high_value
# 0               0.000000           0
# 1               0.000000           0
# 2               0.000000           1
# 3               0.000000           1
# 4               0.000000           1
# 5               0.000000           1
# 6               0.000000           1
# 7               0.000000           0
# 8               0.000000           0
# 9               0.000000           0
# 10              0.000000           1
# 11              0.000000           0
# 12              0.000000           0
# 13              0.000000           0
# 14              0.000000           0
# 15              0.000000           0
# 16              0.000000           0
# 17              0.000000           0
# 18              0.000000           0
# 19              0.000000           0
# 20              0.000000           0
# 21              0.200000           0
# 22              0.000000           0
# 23              0.000000           0
# 24              0.000000           0
# 25              0.000000           0
# 26              0.000000           0
# 27              0.000000           0
# 28              0.000000           0
# 29              0.000000           0
# ...                  ...         ...
# 216900          1.000000           0
# 216901          1.000000           0
# 216902          1.000000           0
# 216903          1.000000           0
# 216904          0.857143           1
# 216905          1.000000           1
# 216906          1.000000           1
# 216907          1.000000           1
# 216908          0.857143           1
# 216909          1.000000           0
# 216910          1.000000           0
# 216911          0.800000           0
# 216912          1.000000           1
# 216913          0.777778           0
# 216914          0.800000           0
# 216915          1.000000           0
# 216916          1.000000           0
# 216917          0.500000           0
# 216918          1.000000           1
# 216919          1.000000           0
# 216920          0.875000           0
# 216921          1.000000           0
# 216922          0.833333           0
# 216923          1.000000           0
# 216924          1.000000           0
# 216925          1.000000           0
# 216926          0.800000           0
# 216927          1.000000           0
# 216928          1.000000           0
# 216929          0.833333           0
#
# [216930 rows x 13 columns]

# %%
def word_count(word):
    low_count = 0
    high_count = 0
    for i, row in jeopardy.iterrows():
        split_question = row['clean_question'].split(" ")
        if word in split_question:
            if row['high_value'] == 1:
                high_count += 1
            else:
                low_count += 1
    return high_count, low_count


observed_expected = []
comparison_terms = list(terms_used)[:5]
for term in comparison_terms:
    result = word_count(term)
    observed_expected.append(result)

# %%
observed_expected
# Out:
# [(0, 5), (0, 2), (0, 1), (0, 1), (0, 1)]

# %%
high_value_count = jeopardy[jeopardy["high_value"] == 1].shape[0]
low_value_count = jeopardy[jeopardy["high_value"] == 0].shape[0]

chi_squared = []
for obs in observed_expected:
    total = sum(obs)
    total_prop = total / jeopardy.shape[0]
    high_value_exp = total_prop * high_value_count
    low_value_exp = total_prop * low_value_count
    
    observed = np.array([obs[0], obs[1]])
    expected = np.array([high_value_exp, low_value_exp])
    chi_squared.append(chisquare(observed, expected))

chi_squared
# Out:
# [Power_divergenceResult(statistic=1.974882321166757, pvalue=0.15993058334750943),
#  Power_divergenceResult(statistic=0.7899529284667026, pvalue=0.3741143592744989),
#  Power_divergenceResult(statistic=0.3949764642333513, pvalue=0.5296950912486695),
#  Power_divergenceResult(statistic=0.3949764642333513, pvalue=0.5296950912486695),
#  Power_divergenceResult(statistic=0.3949764642333513, pvalue=0.5296950912486695)]

# %% [markdown]
# Statistical Test Result (Chi-Square)
#
# None of the terms had a significant difference in usage between high value and low value rows.
